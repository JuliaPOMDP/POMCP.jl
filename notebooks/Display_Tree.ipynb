# %%
using POMDPModels
using POMCP
import POMDPs
import POMDPToolbox: PreviousObservationUpdater

import POMCP.init_V
import POMDPs.action

problem = POMDPModels.BabyPOMDP(-5, -10)
rng = MersenneTwister(1)

solver = POMCPSolver(rollout_solver=POMDPModels.FeedWhenCrying(),
                     eps=0.01,
                     c=10.0,
                     tree_queries=20, 
                     rng=rng,
                     node_belief_updater=POMDPs.updater(problem))

policy = POMDPs.solve(solver, problem)

b = RootNode(0, POMDPModels.BoolDistribution(0.0), Dict{Any,POMCP.ActNode}())

a = action(policy, b)
# Out:
# false

# %%
# click on the nodes to expand them
POMCPTreeVisualizer(b)
# Out:
# POMCP.POMCPTreeVisualizer(POMCP.RootNode{POMDPModels.BoolDistribution}(1,POMDPModels.BoolDistribution(0.0),Dict{Any,POMCP.ActNode{A,O,BNodeType<:POMCP.BeliefNode{S,A,O,B}}}(false=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(false,18,-17.195553680431924,Dict(false=>POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}(false,15,POMDPModels.BoolDistribution(0.02409638554216867),Dict(false=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(false,6,-17.671928720806815,Dict(false=>POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}(false,6,POMDPModels.BoolDistribution(0.029868401596924436),Dict(false=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(false,1,-26.20408585645369,Dict(false=>POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}(false,2,POMDPModels.BoolDistribution(0.03128309542601845),Dict(false=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(false,0,0.0,Dict{Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}()),true=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(true,0,0.0,Dict{Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}()))))),true=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(true,3,-18.50430330145428,Dict(false=>POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}(false,3,POMDPModels.BoolDistribution(0.0),Dict(false=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(false,0,0.0,Dict{Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}()),true=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(true,1,-13.274892636708156,Dict(false=>POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}(false,2,POMDPModels.BoolDistribution(0.0),Dict(false=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(false,0,0.0,Dict{Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}()),true=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(true,0,0.0,Dict{Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}()))))))),true=>POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}(true,2,POMDPModels.BoolDistribution(0.0),Dict(false=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(false,0,0.0,Dict{Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}()),true=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(true,0,0.0,Dict{Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}()))))))),true=>POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}(true,2,POMDPModels.BoolDistribution(0.5256994144437216),Dict(false=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(false,0,0.0,Dict{Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}()),true=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(true,0,0.0,Dict{Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}()))))),true=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(true,7,-16.692282417067275,Dict(false=>POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}(false,8,POMDPModels.BoolDistribution(0.0),Dict(false=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(false,3,-9.073333399862012,Dict(false=>POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}(false,4,POMDPModels.BoolDistribution(0.02409638554216867),Dict(false=>POMCP.ActNode{Bool,Bool,POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}}(false,1,-8.422888021944756,Dict(true=>POMCP.ObsNode{Bool,Bool,Bool,POMDPModels.BoolDistribution}(true,2,POMDPModels.BoolDistribution(0.5256994144437216),Dict(false=>POMCP.ActNode{Bool,Bo ...
